# %% [markdown]
# First try
# =========
#
# With Python
# -----------

# %%
print("Hello World!")
# Out:
# hello

# %% [markdown]
# Image
# =====
#
# ![](attachment:../image/a05-rnd-ok.png)
#
# Columns
# =======
#
# Column 1
# --------
#
# -   Lorem ipsum
#
# ![](attachment:../image/a05-rnd-ok.png)
#
# Column 2
# --------
#
# -   Lorem ipsum
#
# $$
# e=mc^2
# $$
